# %%
from tkinter import *

# %%
root=Tk()
e=Entry(root,width=50,borderwidth=3)
e.grid(row=0,column=0,columnspan=3,padx=50,pady=10)
def button_click(n):
    current=e.get()
    e.delete(0,END)
    e.insert(0,str(current)+str(n))
def button_ad():
    first_num=e.get()
    global f_num
    global math
    math='addition'
    f_num=int(first_num)
    e.delete(0,END)

def button_sb():
    third_num=e.get()
    global t_num
    global math
    math='subtraction'
    t_num=int(third_num)
    e.delete(0,END)
def button_mu():
    for_num=e.get()
    global f_num
    global math
    math='multiply'
    f_num=int(for_num)
    e.delete(0,END)
def button_d():
    fi_num=e.get()
    global fv_num
    global math
    math='division'
    fv_num=int(fi_num)
    e.delete(0,END)
def button_m():
    s_num=e.get()
    global si_num
    global math
    math='mod'
    si_num=int(s_num)
    e.delete(0,END)
def button_cl():
    e.delete(0,END)
def button_equ():
    second_num=e.get()
    e.delete(0,END)
    if math=='addition':
        e.insert(0,f_num+int(second_num))
    elif math=='subtraction':
        e.insert(0,t_num-int(second_num))
    elif math=='multiply':
        e.insert(0,f_num*int(second_num))
    elif math=='division':
        e.insert(0,fv_num/int(second_num))
    elif math=='mod':
        e.insert(0,si_num/int(second_num))
button1=Button(root,text="1",padx=40,pady=20,command=lambda:button_click("1"))
button2=Button(root,text="2",padx=40,pady=20,command=lambda:button_click("2"))
button3=Button(root,text="3",padx=40,pady=20,command=lambda:button_click("3"))
button4=Button(root,text="4",padx=40,pady=20,command=lambda:button_click("4"))
button5=Button(root,text="5",padx=40,pady=20,command=lambda:button_click("5"))
button6=Button(root,text="6",padx=40,pady=20,command=lambda:button_click("6"))
button7=Button(root,text="7",padx=40,pady=20,command=lambda:button_click("7"))
button8=Button(root,text="8",padx=40,pady=20,command=lambda:button_click("8"))
button9=Button(root,text="9",padx=40,pady=20,command=lambda:button_click("9"))
button0=Button(root,text="0",padx=40,pady=20,command=lambda:button_click("0"))
button_add=Button(root,text="+",padx=40,pady=20,command=button_ad)
button_sub=Button(root,text="-",padx=40,pady=20,command=button_sb)
button_mul=Button(root,text="*",padx=40,pady=20,command=button_mu)
button_div=Button(root,text='/',padx=40,pady=20,command=button_d)
button_mod=Button(root,text="%",padx=40,pady=20,command=button_m)
button_eq=Button(root,text="=",padx=40,pady=20,command=button_equ)
button_clr=Button(root,text='clear',padx=40,pady=20,command=button_cl)
button1.grid(row=1,column=0)
button2.grid(row=1,column=1)
button3.grid(row=1,column=2)
button4.grid(row=2,column=0)
button5.grid(row=2,column=1)
button6.grid(row=2,column=2)
button7.grid(row=3,column=0)
button8.grid(row=3,column=1)
button9.grid(row=3,column=2)
button0.grid(row=4,column=0)
button_add.grid(row=4,column=1)
button_eq.grid(row=4,column=2)
button_sub.grid(row=4,column=3)
button_mul.grid(row=3,column=3)
button_div.grid(row=2,column=3)
button_mod.grid(row=1,column=3)
button_clr.grid(row=5,column=0)
root.mainloop()
